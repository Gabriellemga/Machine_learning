# %% [markdown]
# # Precificando mais casas

# %% [markdown]
# <img src="https://github.com/afonsosr2/data-science-regressao-linear/blob/main/imagens/precificando_mais_casas.webp?raw=true" alt="Imagem de uma casa e suas características para precificação" width=720>

# %% [markdown]
# Agora chegou a hora de testarmos o nosso modelo para mais casas!

# %% [markdown]
# ### **Lendo o DataFrame com as casas a precificar**

# %%
# Lendo a base das casas a precificar
...

# %%
# Ajustando a coluna dos dados
...

# %%
# Calculando o logaritmo das variaveis
...

# %% [markdown]
# ### **Importando o modelo salvo em pickle**

# %%
# Importando o modelo
...

# %% [markdown]
# ### **Estimando o preço das casas**

# %%
# Prevendo os valores das casas
...

# %%
# Exibindo os valores em reais
...
